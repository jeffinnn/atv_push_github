# %%
lista = [20, 5, 10, 15, 28, 30]

soma = 0
contagem = 0
for valor in lista:
  soma = soma + valor

for elemeto in lista:
  contagem = contagem + 1

media = soma / contagem

print((f"Sua média é de: {media}").replace (".", ","))
# Out:
# Sua média é de: 18,0

# %%
lista = [20, 5, 10, 15, 28, 30]
soma = 0
contagem = 0
for valor in lista:
  soma = soma + valor

for elemeto in lista:
  contagem = contagem + 1

media = soma / contagem

print((f"Sua média é de: {media}").replace (".", ","))

# %% [markdown]
# https://colab.research.google.com/drive/1vHzibQWd7-s_AP2eXTLphsnUFzyi5YyO?usp=sharing
